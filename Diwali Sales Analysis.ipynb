# %% [markdown]
# 🎉 Introduction: Diwali Sales Analysis
# Diwali—the Festival of Lights—is not only a time of joy and celebration but also one of the most vibrant shopping seasons in India. Each year, millions of consumers engage in buying across diverse product categories, from traditional sweets and clothing to modern electronics and gifts. This surge in purchasing behavior presents a golden opportunity for businesses to connect with their customers and boost their revenue.
#
# The Diwali Sales Analysis project dives deep into sales data collected during this festive period to uncover valuable insights about buyer demographics, spending patterns, and product preferences. Through powerful visualizations and data-driven exploration, this analysis highlights key trends such as which age groups and occupations are most active, which states lead in sales, and which product categories shine brightest.
#
# By understanding these patterns, businesses can tailor their marketing strategies, optimize inventory, and enhance customer engagement — ultimately lighting the way to greater success during one of India’s most cherished celebrations.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt #visualizing data
# %matplotlib inline 
import seaborn as sns

# %%
df = pd.read_csv('Diwali sales Data.csv', encoding='unicode_escape')

# %%
df.shape  #data frame
# Out:
# (11251, 15)

# %%
df.head(10)  #0to5 in head() you can assing in bracket
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.drop(['Status','unnamed1'], axis=1 , inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
#display the null values if false is called not empty true means the box is empty
pd.isnull(df)
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
#check for null values       #before amount
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %% [markdown]
# In amount have 12 null values

# %%
df.shape #2coloums are droped because of empty
# Out:
# (11251, 13)

# %%
#drop null values 
df.dropna(inplace=True)      #before                            #after

# %% [markdown]
#                              | Name   | Age | City     | | Name  | Age | City|
#                              |--------|-----|----------|
#                              | Sam    | 21  | Chennai  | |-------|-----|---------|
#                              | Riya   |     | Delhi    | | Sam   | 21  | Chennai |
#                              | Rahul  | 25  |          |

# %%
df.shape
# Out:
# (11239, 13)

# %%
#check for null values   #after amount
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
#Amount            11239 non-null  float64
#I want to change data type   float -> int
df['Amount'] = df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int32')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.rename(columns={"Marital_Status":"Status_of_Marital"})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28
# 1      1000732       Kartik  P00110942      F     26-35   35
# 2      1001990        Bindu  P00118542      F     26-35   35
# 3      1001425       Sudevi  P00237842      M      0-17   16
# 4      1000588         Joni  P00057942      M     26-35   28
# ...        ...          ...        ...    ...       ...  ...
# 11246  1000695      Manning  P00296942      M     18-25   19
# 11247  1004089  Reichenbach  P00171342      M     26-35   33
# 11248  1001209        Oshin  P00201342      F     36-45   40
# 11249  1004023       Noonan  P00059442      M     36-45   37
# 11250  1002744      Brumley  P00281742      F     18-25   19
#
#        Status_of_Marital           State      Zone       Occupation  \
# 0                      0     Maharashtra   Western       Healthcare
# 1                      1  Andhra Pradesh  Southern             Govt
# ...

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
#use describe() for specific columns
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# Exploratory Data Analysis
#
# Gender

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sns.countplot(x='Gender', data=df)
plt.show()

# %%
ax=sns.countplot(x = 'Gender',data = df)

for bars in ax.containers:
    ax.bar_label(bars)
    plt.show()

# %%
df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
# Out:
#   Gender    Amount
# 0      F  74335853
# 1      M  31913276

# %%
sales_gen = df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x = 'Gender',y='Amount',data = sales_gen)
plt.show()

# %% [markdown]
# 📝 Summary
#
# - 📊 Gender Insight:
#   From the above graphs, we can see that most of the buyers are females**, and their purchasing power is greater than that of males**.
#
# - 👥 Age Group Insight:
#   The age group with the highest total spending** is 26-35, indicating that this demographic is the most active in shopping.

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sns.countplot(data = df, x ='Age Group' )
plt.show()

# %%
ax = sns.countplot(data = df, x ='Age Group' , hue = 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)
    plt.show()

# %%
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x='Age Group', y='Amount', data=sales_age)
plt.title('Total Sales by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Total Amount')
plt.show()

# %%
#colouful bars
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x='Age Group', y='Amount', hue='Age Group', data=sales_age, palette='Set2', legend=False)
plt.title('Total Sales by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Total Amount')
plt.show()

# %% [markdown]
# From the above graphs, we observe that most of the buyers are females , and the age group between 26-33 years shows the highest purchasing activity. This indicates that females aged 26-33 are the primary target audience.

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#total number of orders from top 10 states
sales_state = df.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(data = sales_state,x='State',y='Orders')
plt.show()

# %%
#total amount/sales from top 10

sales_state = df.groupby(['State'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state,x ='State',y='Amount')
plt.show()

# %% [markdown]
# ### 📝 Summary of Top 10 States by Total Sales Amount
#
# - 📍 **The state with the highest sales** is likely **Uttar Pradesh** (or whichever your data shows), indicating it is the most active market.
# - 🏙️ **Urban and economically strong states** dominate the top 10 list — showing that purchasing power and population density play a key role in driving sales.
# - 🔢 States like **Karnataka** and **Delhi** also contribute significantly, suggesting they are key regions for marketing focus.
#
# This analysis helps identify **target regions** where customers are more likely to spend, which is valuable for future promotional campaigns and inventory planning.

# %% [markdown]
# Marital Status

# %%
ax = sns.countplot(data=df,x = 'Marital_Status')

sns.set(rc={'figure.figsize':(10,5)})
for bars in ax.containers:
    ax.bar_label(bars)
    plt.show()

# %%
sales_state = df.groupby(['Marital_Status',"Gender"],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data=sales_state,x='Marital_Status',y="Amount",hue="Gender")
plt.show()

# %% [markdown]
# From above graphs we can see that most of the buyers are married(women) and they have high purchasing power

# %% [markdown]
# Occupation

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data=df,x='Occupation')

for bar in ax.containers:
    ax.bar_label(bars)
plt.show()

# %% [markdown]
# ### 🧑‍💼 Summary of Occupation Distribution
#
# From the chart, we can see which occupations dominate buyer demographics. This helps understand which professional groups are most engaged in purchasing, guiding targeted marketing and promotional strategies.

# %% [markdown]
# Product Category

# %%
sns.set(rc={"figure.figsize":(20,5)})
ax = sns.countplot(data=df,x="Product_Category")

for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state,x = "Product_Category",y= 'Amount')
plt.show()

# %% [markdown]
# ### 📦 Summary of Top-Selling Product Categories
#
# The chart highlights the top 10 product categories based on total sales. It reveals which categories contribute the most to revenue. This helps in identifying which products are most popular and should be prioritized for stock, discounts, and marketing.

# %%
sales_state = df.groupby(['Product_ID'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(data = sales_state, x ='Product_ID',y = 'Orders')
plt.show()

# %% [markdown]
# ### 📊 Summary of Most Ordered Products
#
# This chart shows the top 10 products with the highest number of orders. These products are the most popular among customers and should be prioritized for restocking and promotional efforts.

# %%
#top 10 most sold products(some thing as above)
fig1,ax1 = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
plt.show()

# %% [markdown]
# ### 🛒 Top 10 Most Sold Products
#
# The bar chart shows the top 10 products based on the total number of orders. These are the most frequently bought items and play a key role in overall sales performance. Such insights are helpful for demand forecasting and inventory planning.

# %% [markdown]
# Conclusion:
#
# Married women aged 26 to 35 years from Uttar Pradesh, Maharashtra, and Karnataka, working in IT, healthcare, and aviation sectors, are the most active buyers. They predominantly purchase products from the food, clothing, and electronics categories.
